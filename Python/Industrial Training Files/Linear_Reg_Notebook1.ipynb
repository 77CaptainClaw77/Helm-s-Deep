# %%
import pandas as pd

# %%
#mydata=pd.readcsv('data1.csv')

# %%
mydata=pd.read_csv('data1.csv',names=['population','profit'])

# %%
mydata
# Out:
#     population    profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# 5       8.3829  11.88600
# 6       7.4764   4.34830
# 7       8.5781  12.00000
# 8       6.4862   6.59870
# 9       5.0546   3.81660
# 10      5.7107   3.25220
# 11     14.1640  15.50500
# 12      5.7340   3.15510
# 13      8.4084   7.22580
# 14      5.6407   0.71618
# 15      5.3794   3.51290
# 16      6.3654   5.30480
# 17      5.1301   0.56077
# 18      6.4296   3.65180
# 19      7.0708   5.38930
# 20      6.1891   3.13860
# 21     20.2700  21.76700
# 22      5.4901   4.26300
# 23      6.3261   5.18750
# 24      5.5649   3.08250
# 25     18.9450  22.63800
# 26     12.8280  13.50100
# 27     10.9570   7.04670
# 28     13.1760  14.69200
# 29     22.2030  24.14700
# ..         ...       ...
# 67     10.2360   7.77540
# 68      5.4994   1.01730
# 69     20.3410  20.99200
# 70     10.1360   6.67990
# 71      7.3345   4.02590
# ...

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
mydata.describe()
# Out:
#        population     profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
import matplotlib.pyplot as plt

# %%
'''jdshdjfd
kadsjljkads'''
# Out:
# 'jdshdjfd\nkadsjljkads'

# %%
# %matplotlib inline

# %%
mydata.plot(kind='scatter',x='population',y='profit',figsize=(20,10))

# %%
import numpy as np

# %%
help(mydata.plot)
# Out:
# Help on FramePlotMethods in module pandas.plotting._core object:
#
# class FramePlotMethods(BasePlotMethods)
#  |  DataFrame plotting accessor and method
#  |
#  |  Examples
#  |  --------
#  |  >>> df.plot.line()
#  |  >>> df.plot.scatter('x', 'y')
#  |  >>> df.plot.hexbin()
#  |
#  |  These plotting methods can also be accessed by calling the accessor as a
#  |  method with the ``kind`` argument:
#  |  ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
#  |
#  |  Method resolution order:
#  |      FramePlotMethods
#  |      BasePlotMethods
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      pandas.core.accessor.DirNamesMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...

# %%
def computeCost(X,y,theta):
    return np.sum(np.power(((X*theta.T)-y),2))/ (2*len(X))

# %%
mydata.insert(0,'Ones',1)

# %%
X=mydata.iloc[:,:2]
y=mydata.iloc[:,2:3]

# %%
X
# Out:
#     Ones  population
# 0      1      6.1101
# 1      1      5.5277
# 2      1      8.5186
# 3      1      7.0032
# 4      1      5.8598
# 5      1      8.3829
# 6      1      7.4764
# 7      1      8.5781
# 8      1      6.4862
# 9      1      5.0546
# 10     1      5.7107
# 11     1     14.1640
# 12     1      5.7340
# 13     1      8.4084
# 14     1      5.6407
# 15     1      5.3794
# 16     1      6.3654
# 17     1      5.1301
# 18     1      6.4296
# 19     1      7.0708
# 20     1      6.1891
# 21     1     20.2700
# 22     1      5.4901
# 23     1      6.3261
# 24     1      5.5649
# 25     1     18.9450
# 26     1     12.8280
# 27     1     10.9570
# 28     1     13.1760
# 29     1     22.2030
# ..   ...         ...
# 67     1     10.2360
# 68     1      5.4994
# 69     1     20.3410
# 70     1     10.1360
# 71     1      7.3345
# 72     1      6.0062
# 73     1      7.2259
# 74     1      5.0269
# 75     1      6.5479
# 76     1      7.5386
# 77     1      5.0365
# ...

# %%
y
# Out:
#       profit
# 0   17.59200
# 1    9.13020
# 2   13.66200
# 3   11.85400
# 4    6.82330
# 5   11.88600
# 6    4.34830
# 7   12.00000
# 8    6.59870
# 9    3.81660
# 10   3.25220
# 11  15.50500
# 12   3.15510
# 13   7.22580
# 14   0.71618
# 15   3.51290
# 16   5.30480
# 17   0.56077
# 18   3.65180
# 19   5.38930
# 20   3.13860
# 21  21.76700
# 22   4.26300
# 23   5.18750
# 24   3.08250
# 25  22.63800
# 26  13.50100
# 27   7.04670
# 28  14.69200
# 29  24.14700
# ..       ...
# 67   7.77540
# 68   1.01730
# 69  20.99200
# 70   6.67990
# 71   4.02590
# 72   1.27840
# 73   3.34110
# 74  -2.68070
# 75   0.29678
# 76   3.88450
# 77   5.70140
# 78   6.75260
# 79   2.05760
# 80   0.47953
# 81   0.20421
# 82   0.67861
# 83   7.54350
# 84   5.34360
# 85   4.24150
# 86   6.79810
# 87   0.92695
# 88   0.15200
# 89   2.82140
# 90   1.84510
# 91   4.29590
# 92   7.20290
# 93   1.98690
# 94   0.14454
# 95   9.05510
# 96   0.61705
#
# [97 rows x 1 columns]

# %%
X=np.matrix(X)
y=np.matrix(y)
theta=np.matrix(np.array([0,0]))

# %%
X
# Out:
# matrix([[ 1.    ,  6.1101],
#         [ 1.    ,  5.5277],
#         [ 1.    ,  8.5186],
#         [ 1.    ,  7.0032],
#         [ 1.    ,  5.8598],
#         [ 1.    ,  8.3829],
#         [ 1.    ,  7.4764],
#         [ 1.    ,  8.5781],
#         [ 1.    ,  6.4862],
#         [ 1.    ,  5.0546],
#         [ 1.    ,  5.7107],
#         [ 1.    , 14.164 ],
#         [ 1.    ,  5.734 ],
#         [ 1.    ,  8.4084],
#         [ 1.    ,  5.6407],
#         [ 1.    ,  5.3794],
#         [ 1.    ,  6.3654],
#         [ 1.    ,  5.1301],
#         [ 1.    ,  6.4296],
#         [ 1.    ,  7.0708],
#         [ 1.    ,  6.1891],
#         [ 1.    , 20.27  ],
#         [ 1.    ,  5.4901],
#         [ 1.    ,  6.3261],
#         [ 1.    ,  5.5649],
#         [ 1.    , 18.945 ],
#         [ 1.    , 12.828 ],
#         [ 1.    , 10.957 ],
#         [ 1.    , 13.176 ],
#         [ 1.    , 22.203 ],
#         [ 1.    ,  5.2524],
#         [ 1.    ,  6.5894],
#         [ 1.    ,  9.2482],
# ...

# %%
y
# Out:
# matrix([[17.592  ],
#         [ 9.1302 ],
#         [13.662  ],
#         [11.854  ],
#         [ 6.8233 ],
#         [11.886  ],
#         [ 4.3483 ],
#         [12.     ],
#         [ 6.5987 ],
#         [ 3.8166 ],
#         [ 3.2522 ],
#         [15.505  ],
#         [ 3.1551 ],
#         [ 7.2258 ],
#         [ 0.71618],
#         [ 3.5129 ],
#         [ 5.3048 ],
#         [ 0.56077],
#         [ 3.6518 ],
#         [ 5.3893 ],
#         [ 3.1386 ],
#         [21.767  ],
#         [ 4.263  ],
#         [ 5.1875 ],
#         [ 3.0825 ],
#         [22.638  ],
#         [13.501  ],
#         [ 7.0467 ],
#         [14.692  ],
#         [24.147  ],
#         [-1.22   ],
#         [ 5.9966 ],
#         [12.134  ],
#         [ 1.8495 ],
#         [ 6.5426 ],
#         [ 4.5623 ],
#         [ 4.1164 ],
#         [ 3.3928 ],
#         [10.117  ],
#         [ 5.4974 ],
#         [ 0.55657],
#         [ 3.9115 ],
#         [ 5.3854 ],
#         [ 2.4406 ],
#         [ 6.7318 ],
# ...

# %%
X.shape
# Out:
# (97, 2)

# %%
y.shape
# Out:
# (97, 1)

# %%
theta.shape
# Out:
# (1, 2)

# %%
computeCost(X,y,theta)#initial cost at [0,0]
# Out:
# 32.072733877455676

# %%
def gradientDescent(X,y,theta,alpha,iterations):
    temp=np.matrix(np.zeros(theta.shape))
    parameters=2
    cost=np.zeros(iterations)
    for i in range(iterations):
        error=(X*theta.T)-y
        for j in range(parameters):
            term=np.multiply(error,X[:,j])
            temp[0,j]=theta[0,j]-((alpha/len(X))*np.sum(term))
        theta=temp
        cost[i]=computeCost(X,y,theta)
    return theta,cost

# %%
a,b=gradientDescent(X,y,theta,0.01,20000)

# %%
b[-1]
# Out:
# 4.476971375975179

# %%
a
# Out:
# matrix([[-3.89578088,  1.19303364]])

# %%
x=np.linspace(mydata.population.min(),mydata.population.max(),100)
f=a[0,0]+a[0,1] * x
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(x,f,'r')
ax.scatter(mydata.population,mydata.profit,color='g')

# %%
y_axis=b
x_axis=np.arange(20000)
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(x_axis,y_axis,'r')

# %%
data_set_a=pd.read_csv('data1.csv',names=['col1','col2'])

# %%
data_set_a
# Out:
#        col1      col2
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# 5    8.3829  11.88600
# 6    7.4764   4.34830
# 7    8.5781  12.00000
# 8    6.4862   6.59870
# 9    5.0546   3.81660
# 10   5.7107   3.25220
# 11  14.1640  15.50500
# 12   5.7340   3.15510
# 13   8.4084   7.22580
# 14   5.6407   0.71618
# 15   5.3794   3.51290
# 16   6.3654   5.30480
# 17   5.1301   0.56077
# 18   6.4296   3.65180
# 19   7.0708   5.38930
# 20   6.1891   3.13860
# 21  20.2700  21.76700
# 22   5.4901   4.26300
# 23   6.3261   5.18750
# 24   5.5649   3.08250
# 25  18.9450  22.63800
# 26  12.8280  13.50100
# 27  10.9570   7.04670
# 28  13.1760  14.69200
# 29  22.2030  24.14700
# ..      ...       ...
# 67  10.2360   7.77540
# 68   5.4994   1.01730
# 69  20.3410  20.99200
# 70  10.1360   6.67990
# 71   7.3345   4.02590
# 72   6.0062   1.27840
# 73   7.2259   3.34110
# 74   5.0269  -2.68070
# 75   6.5479   0.29678
# ...

# %%
type(data_set_a)
# Out:
# pandas.core.frame.DataFrame

# %%
a=data_set_a.iloc[:,0:]

# %%
a
# Out:
#        col1      col2
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# 5    8.3829  11.88600
# 6    7.4764   4.34830
# 7    8.5781  12.00000
# 8    6.4862   6.59870
# 9    5.0546   3.81660
# 10   5.7107   3.25220
# 11  14.1640  15.50500
# 12   5.7340   3.15510
# 13   8.4084   7.22580
# 14   5.6407   0.71618
# 15   5.3794   3.51290
# 16   6.3654   5.30480
# 17   5.1301   0.56077
# 18   6.4296   3.65180
# 19   7.0708   5.38930
# 20   6.1891   3.13860
# 21  20.2700  21.76700
# 22   5.4901   4.26300
# 23   6.3261   5.18750
# 24   5.5649   3.08250
# 25  18.9450  22.63800
# 26  12.8280  13.50100
# 27  10.9570   7.04670
# 28  13.1760  14.69200
# 29  22.2030  24.14700
# ..      ...       ...
# 67  10.2360   7.77540
# 68   5.4994   1.01730
# 69  20.3410  20.99200
# 70  10.1360   6.67990
# 71   7.3345   4.02590
# 72   6.0062   1.27840
# 73   7.2259   3.34110
# 74   5.0269  -2.68070
# 75   6.5479   0.29678
# ...

# %%
#retrying with higher values of alpha
#-----------------------------------------------------------------------------------------------------------

# %%
a,b=gradientDescent(X,y,theta,0.1,150)

# %%
a
# Out:
# matrix([[-5.05325205e+127, -5.03007112e+128]])

# %%
b[-1]
# Out:
# 1.0506940641959555e+259
